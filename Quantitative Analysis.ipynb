# %%
# !python3 --version
# Out:
# Python 3.9.16

# %%
import pandas as pd
import io
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5059d622-e414-4249-aff8-5d285e07df6b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5059d622-e414-4249-aff8-5d285e07df6b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Convert the bytes object to a string
# Read the Excel file and specify the sheet name
excel_data = uploaded['Chat GPT Training Data NEW.xlsx']
sheet1 = pd.read_excel(io.BytesIO(excel_data), sheet_name='Testing Different Nationalities')
sheet2 = pd.read_excel(io.BytesIO(excel_data), sheet_name='Testing With Different Language')
sheet3 = pd.read_excel(io.BytesIO(excel_data), sheet_name='Testing With Swapping Words (Ad')
sheet4 = pd.read_excel(io.BytesIO(excel_data), sheet_name='Testing With Separated Responsi')
sheet5 = pd.read_excel(io.BytesIO(excel_data), sheet_name='Testing With Coded Language (Br')

df = pd.concat([sheet1, sheet2, sheet3, sheet4, sheet5])

# Print the contents of the sheet
df.head()
# Out:
#   Country Who Tried it                                  Template Sentence  \
# 0   China          Sam  I am planning a trip to [COUNTRY] with my fami...
# 1   China          Sam                                                NaN
# 2   China          Sam                                                NaN
# 3   China          Sam                                                NaN
# 4   China          Sam                                                NaN
#
#   Input Phrase                                     Chatgpt Output Date  \
# 0        China  Language barrier: Chinese is the official lang...  NaT
# 1          NaN  Cultural differences: China has a unique cultu...  NaT
# 2          NaN  Food and water: Food hygiene standards in Chin...  NaT
# 3          NaN  Pollution: Major cities in China have high lev...  NaT
# 4          NaN  Transportation: China has a vast transportatio...  NaT
#
#    Screenshot (If it's a particularly biased response) Qualitative Analysis  \
# ...

# %% [markdown]
# QUALITATIVE ANALYSIS TRENDS

# %%
df['Qualitative Analysis'].unique()
# Out:
# array(['Nothing',
#        'Harms of Representation, allocation, and quality of service', nan,
#        'Disinformation and influence operations', 'Acceleration',
#        'Overreliance',
#        'Potential for risky emergent behaviors - acquiring resources',
#        'Harmful Content',
#        'Potential for risky emergent behaviors - code for illegal activity',
#        'Potential for risky emergent behaviors - avoiding being shut down',
#        'Harmful Content - Harassing, demeaning, and hateful content'],
#       dtype=object)

# %% [markdown]
# MODELING

# %%
pip install allennlp==2.10.1 allennlp-models==2.10.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 730.2/730.2 KB 35.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 464.5/464.5 KB 37.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 53.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 75.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.2/248.2 KB 27.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 62.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 880.6/880.6 KB 49.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
predictor = Predictor.from_path("https://storage.googleapis.com/allennlp-public-models/stanford-sentiment-treebank-roberta.2021-03-11.tar.gz")
predictor.predict("a very well-made, funny and entertaining picture.")

# %% [markdown]
# MODEL VISUALIZATIONS

# %%
import matplotlib.pyplot as plt
import seaborn as sns
